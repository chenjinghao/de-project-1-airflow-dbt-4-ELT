# %%
import pandas as pd
import json

# %%
with open("0_PCLA_stocks_news.json", "r") as file:
    stock_news = json.load(file)

# %%
print(stock_news['feed'])
# Out:
# [{'title': 'PicoCELA Inc. - American Depositary Shares (Nasdaq:PCLA) Stock Quote', 'url': 'https://markets.financialcontent.com/stocks/quote?Symbol=537%3A2578431417', 'time_published': '20251223T190919', 'authors': ['NULL'], 'summary': 'This article provides a stock quote and related financial performance data for PicoCELA Inc. (Nasdaq: PCLA). It includes current trading information, historical price ranges, and a collection of recent news headlines related to the company and the broader information technology sector. The company is publicly traded on the Nasdaq Stock Market.', 'banner_image': 'NULL', 'source': 'FinancialContent', 'category_within_source': 'General', 'source_domain': 'FinancialContent', 'topics': [{'topic': 'financial_markets', 'relevance_score': '0.927170'}, {'topic': 'technology', 'relevance_score': '0.803310'}], 'overall_sentiment_score': -0.15962, 'overall_sentiment_label': 'Somewhat-Bearish', 'ticker_sentiment': [{'ticker': 'PCLA', 'relevance_score': '1.000000',
# ...

# %%
df = pd.DataFrame(stock_news['feed'])
print(df.head())
# Out:
#                                                title  \
# 0  PicoCELA Inc. - American Depositary Shares (Na...
# 1  PicoCELA Inc. Announces Annual General Meeting...
# 2  PicoCELA (NASDAQ:PCLA) Given “Sell (E+)” Ratin...
# 3  Spirit Advisors Client PicoCELA Inc completes ...
# 4  独自メッシュWi-Fi技術がスマート工場で高評価、成長軌道描くPicoCELAの挑戦：組み込...
#
#                                                  url   time_published  \
# 0  https://markets.financialcontent.com/stocks/qu...  20251223T190919
# 1  https://www.tipranks.com/news/company-announce...  20251212T231012
# 2  https://www.defenseworld.net/2025/10/15/picoce...  20251015T073420
# 3  https://laotiantimes.com/2025/01/20/spirit-adv...  20250120T120950
# 4  https://monoist.itmedia.co.jp/mn/articles/2012...  20201225T100000
#
#                               authors  \
# 0                              [NULL]
# 1  [TipRanks Auto-Generated Newsdesk]
# 2               [Defense World Staff]
# 3                     [Laotian Times]
# ...

# %%
df.shape
# Out:
# (7, 13)
