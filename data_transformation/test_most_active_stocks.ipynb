# %%
import pandas as pd
import json

# %%
with open("most_active_stocks.json", "r") as file:
    most_active_stocks = json.load(file)

# %%
print(most_active_stocks)
# Out:
# [{'ticker': 'VIVK', 'price': '0.0348', 'change_amount': '-0.0118', 'change_percentage': '-25.3219%', 'volume': '447856202'}, {'ticker': 'NCL', 'price': '0.256', 'change_amount': '0.0847', 'change_percentage': '49.4454%', 'volume': '305009301'}, {'ticker': 'MWG', 'price': '0.3571', 'change_amount': '0.104', 'change_percentage': '41.0905%', 'volume': '284579355'}, {'ticker': 'SOBR', 'price': '2.37', 'change_amount': '1.07', 'change_percentage': '82.3077%', 'volume': '142596997'}, {'ticker': 'XTKG', 'price': '0.164', 'change_amount': '-0.0001', 'change_percentage': '-0.0609%', 'volume': '132042474'}, {'ticker': 'SIDU', 'price': '2.2', 'change_amount': '0.55', 'change_percentage': '33.3333%', 'volume': '83308991'}, {'ticker': 'SOXS', 'price': '2.985', 'change_amount': '-0.025', 'change_percentage': '-0.8306%', 'volume': '78241754'}, {'ticker': 'WOK', 'price': '0.0328', 'change_amount': '-0.0161', 'change_percentage': '-32.9243%', 'volume': '77694854'}, {'ticker': 'NVDA', 'price': '188.61', 'change_amount': '-0.6', 'change_percentage': '-0.3171%', 'volume': '65375093'}, {'ticker': 'SLV', 'price': '65.22', 'change_amount': '0.38', 'change_percentage': '0.5861%', 'volume': '58763757'}, {'ticker': 'TSLL', 'price': '22.3432', 'change_amount': '-0.0568', 'change_percentage': '-0.2536%', 'volume': '49699521'}, {'ticker': 'PLUG', 'price': '2.1', 'change_amount': '0.05', 'change_percentage': '2.439%', 'volume': '47449006'}, {'ticker': 'TZA', 'price': '6.94', 'change_amount': '-0.04', 'change_percentage': '-0.5731%', 'volume': '42458373'}, {'ticker': 'TSLA', 'price': '485.4', 'change_amount': '-0.16', 'change_percentage': '-0.033%', 'volume': '41255134'}, {'ticker': 'SPY', 'price': '690.27', 'change_amount': '2.31', 'change_percentage': '0.3358%', 'volume': '39418438'}, {'ticker': 'INTC', 'price': '36.16', 'change_amount': '-0.19', 'change_percentage': '-0.5227%', 'volume': '37401505'}, {'ticker': 'ELOG', 'price': '1.65', 'change_amount': '0.23', 'change_percentage': '16.1972%', 'volume': '36173513'}, {'ticker': 'NKE', 'price': '60.01', 'change_amount': '2.67', 'change_percentage': '4.6564%', 'volume': '36046330'}, {'ticker': 'APLT', 'price': '0.1154', 'change_amount': '-0.0003', 'change_percentage': '-0.2593%', 'volume': '34798352'}, {'ticker': 'PATH', 'price': '17.15', 'change_amount': '1.19', 'change_percentage': '7.4561%', 'volume': '34577890'}]

# %%
df = pd.DataFrame(most_active_stocks)

# %%
print(df)
# Out:
#    ticker    price change_amount change_percentage     volume
# 0    VIVK   0.0348       -0.0118         -25.3219%  447856202
# 1     NCL    0.256        0.0847          49.4454%  305009301
# 2     MWG   0.3571         0.104          41.0905%  284579355
# 3    SOBR     2.37          1.07          82.3077%  142596997
# 4    XTKG    0.164       -0.0001          -0.0609%  132042474
# 5    SIDU      2.2          0.55          33.3333%   83308991
# 6    SOXS    2.985        -0.025          -0.8306%   78241754
# 7     WOK   0.0328       -0.0161         -32.9243%   77694854
# 8    NVDA   188.61          -0.6          -0.3171%   65375093
# 9     SLV    65.22          0.38           0.5861%   58763757
# 10   TSLL  22.3432       -0.0568          -0.2536%   49699521
# 11   PLUG      2.1          0.05            2.439%   47449006
# 12    TZA     6.94         -0.04          -0.5731%   42458373
# 13   TSLA    485.4         -0.16           -0.033%   41255134
# 14    SPY   690.27          2.31           0.3358%   39418438
# 15   INTC    36.16         -0.19          -0.5227%   37401505
# 16   ELOG     1.65          0.23          16.1972%   36173513
# 17    NKE    60.01          2.67           4.6564%   36046330
# 18   APLT   0.1154       -0.0003          -0.2593%   34798352
# 19   PATH    17.15          1.19           7.4561%   34577890
